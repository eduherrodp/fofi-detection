# %%
import pathlib 
import numpy as np
from skimage import io
import matplotlib.pyplot as plt

# %%
# Información del dataset
import pathlib
initial_count = 0
total_count = 0
path_fire = 'dataset/fire'
path_nofire = 'dataset/nofire'
for path in pathlib.Path(path_fire).iterdir():
    if path.is_file():
        initial_count += 1
for path in pathlib.Path(path_nofire).iterdir():
    if path.is_file():
        initial_count += 1

print('Número de instancias: ', initial_count)
# Out:
# Número de instancias:  1520

# %%
# Prueba lectura de imágen 
path_img = 'dataset/fire/fire_0001.jpg'
image = io.imread(path_img)/255.0

print("- Dimensiones de la imagen:")
plt.imshow(image)
print(image.shape)

# Separación de canales
# Out:
# - Dimensiones de la imagen:
# (250, 250, 3)

# %%
plt.imshow(image[:,:,0],vmin=0,vmax=1)
plt.title("Canal Rojo")
plt.figure()
plt.imshow(image[:,:,1],vmin=0,vmax=1)
plt.title("Canal Verde")
plt.figure()
plt.imshow(image[:,:,2],vmin=0,vmax=1)
plt.title("Canal Azul")
# Out:
# Text(0.5, 1.0, 'Canal Azul')
